# %%
# !wget --no-check-certificate \
  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
  -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-06-16 04:52:22--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.206.128, 2a00:1450:400c:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.206.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  84.7MB/s    in 0.8s
#
# 2020-06-16 04:52:23 (84.7 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
import os

# %%
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
os.listdir(train_dir)
# Out:
# ['cats', 'dogs']

# %%
print('total training cat images :', len(os.listdir(train_cats_dir ) ))
print('total training dog images :', len(os.listdir(train_dogs_dir ) ))

print('total validation cat images :', len(os.listdir( validation_cats_dir ) ))
print('total validation dog images :', len(os.listdir( validation_dogs_dir ) ))
# Out:
# total training cat images : 1000
# total training dog images : 1000
# total validation cat images : 500
# total validation dog images : 500

# %% [markdown]
# Let's set up data generators that will read pictures in our source folders, convert them to float32 tensors, and feed them (with their labels) to our network

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# Rescale all images by 1/255

train_datagen = ImageDataGenerator(rescale = 1.0/255.)
valid_datagen = ImageDataGenerator(rescale = 1.0/255.)

# %%
# Flow training and validation images using train_datagen and valid_datagen, respectively

train_generator = train_datagen.flow_from_directory(
    train_dir,
    batch_size = 20,
    target_size = (150,150),
    class_mode = 'binary'
)

valid_generator = valid_datagen.flow_from_directory(
    validation_dir,
    batch_size = 20,
    target_size = (150,150),
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# Let's create the model

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
                    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,3)),
                    tf.keras.layers.MaxPooling2D((2,2)),
                    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
                    tf.keras.layers.MaxPooling2D((2,2)),
                    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
                    tf.keras.layers.MaxPooling2D((2,2)),
                    tf.keras.layers.Flatten(),
                    tf.keras.layers.Dense(512, activation='relu'),
                    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(optimizer=RMSprop(lr=0.001), 
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data = valid_generator,
    steps_per_epoch = 100,
    epochs = 50,
    validation_steps = 50,
)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.3098 - accuracy: 0.8550 - val_loss: 0.6855 - val_accuracy: 0.7210
# Epoch 2/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2359 - accuracy: 0.9075 - val_loss: 0.8620 - val_accuracy: 0.6990
# Epoch 3/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1833 - accuracy: 0.9350 - val_loss: 1.0251 - val_accuracy: 0.7050
# Epoch 4/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1236 - accuracy: 0.9545 - val_loss: 1.1730 - val_accuracy: 0.6980
# Epoch 5/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0752 - accuracy: 0.9770 - val_loss: 1.6726 - val_accuracy: 0.6890
# Epoch 6/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0726 - accuracy: 0.9795 - val_loss: 1.4320 - val_accuracy: 0.7160
# Epoch 7/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0875 - accuracy: 0.9830 - val_loss: 1.4803 - val_accuracy: 0.7140
# Epoch 8/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0573 - accuracy: 0.9875 - val_loss: 1.3666 - val_accuracy: 0.7180
# Epoch 9/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0374 - accuracy: 0.9920 - val_loss: 1.8549 - val_accuracy: 0.7410
# Epoch 10/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0737 - accuracy: 0.9825 - val_loss: 1.6446 - val_accuracy: 0.7040
# Epoch 11/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0230 - accuracy: 0.9950 - val_loss: 2.2635 - val_accuracy: 0.7110
# Epoch 12/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0318 - accuracy: 0.9915 - val_loss: 2.0904 - val_accuracy: 0.7220
# Epoch 13/50
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0343 - accuracy: 0.9960 - val_loss: 2.3244 - val_accuracy: 0.7120
# Epoch 14/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0589 - accuracy: 0.9905 - val_loss: 2.1039 - val_accuracy: 0.7090
# Epoch 15/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0264 - accuracy: 0.9965 - val_loss: 2.3825 - val_accuracy: 0.7030
# Epoch 16/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0735 - accuracy: 0.9905 - val_loss: 2.4502 - val_accuracy: 0.7200
# Epoch 17/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0343 - accuracy: 0.9950 - val_loss: 2.7566 - val_accuracy: 0.7090
# Epoch 18/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0409 - accuracy: 0.9940 - val_loss: 2.2618 - val_accuracy: 0.7270
# Epoch 19/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 2.5288 - val_accuracy: 0.7200
# Epoch 20/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0363 - accuracy: 0.9935 - val_loss: 3.0943 - val_accuracy: 0.7030
# Epoch 21/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0373 - accuracy: 0.9925 - val_loss: 3.6775 - val_accuracy: 0.7000
# Epoch 22/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 3.4423 - val_accuracy: 0.7020
# Epoch 23/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0150 - accuracy: 0.9965 - val_loss: 3.1309 - val_accuracy: 0.7030
# Epoch 24/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0028 - accuracy: 0.9985 - val_loss: 3.0748 - val_accuracy: 0.6980
# Epoch 25/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0226 - accuracy: 0.9940 - val_loss: 3.0947 - val_accuracy: 0.6990
# Epoch 26/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1188 - accuracy: 0.9905 - val_loss: 3.1901 - val_accuracy: 0.7070
# Epoch 27/50
# 100/100 [==============================] - 10s 104ms/step - loss: 1.3793e-04 - accuracy: 1.0000 - val_loss: 3.3302 - val_accuracy: 0.6990
# Epoch 28/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 3.6776 - val_accuracy: 0.7090
# Epoch 29/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0187 - accuracy: 0.9965 - val_loss: 3.3965 - val_accuracy: 0.7010
# Epoch 30/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0219 - accuracy: 0.9950 - val_loss: 4.2421 - val_accuracy: 0.7030
# Epoch 31/50
# 100/100 [==============================] - 10s 103ms/step - loss: 8.4112e-05 - accuracy: 1.0000 - val_loss: 4.0527 - val_accuracy: 0.7210
# Epoch 32/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0855 - accuracy: 0.9930 - val_loss: 3.9725 - val_accuracy: 0.7110
# Epoch 33/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 3.6991 - val_accuracy: 0.7050
# Epoch 34/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0157 - accuracy: 0.9965 - val_loss: 4.2439 - val_accuracy: 0.6830
# Epoch 35/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 4.1961 - val_accuracy: 0.7120
# Epoch 36/50
# 100/100 [==============================] - 11s 105ms/step - loss: 5.8337e-07 - accuracy: 1.0000 - val_loss: 4.5605 - val_accuracy: 0.7210
# Epoch 37/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.1093 - accuracy: 0.9890 - val_loss: 4.2916 - val_accuracy: 0.7000
# Epoch 38/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0337 - accuracy: 0.9945 - val_loss: 4.5213 - val_accuracy: 0.6810
# Epoch 39/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0082 - accuracy: 0.9965 - val_loss: 4.8504 - val_accuracy: 0.6950
# Epoch 40/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0122 - accuracy: 0.9980 - val_loss: 5.0467 - val_accuracy: 0.6930
# Epoch 41/50
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0198 - accuracy: 0.9955 - val_loss: 4.3519 - val_accuracy: 0.7130
# Epoch 42/50
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 5.2202 - val_accuracy: 0.6950
# Epoch 43/50
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0428 - accuracy: 0.9915 - val_loss: 3.8551 - val_accuracy: 0.6950
# Epoch 44/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0166 - accuracy: 0.9980 - val_loss: 3.7720 - val_accuracy: 0.7010
# Epoch 45/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 4.8815 - val_accuracy: 0.6980
# Epoch 46/50
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0200 - accuracy: 0.9950 - val_loss: 5.0699 - val_accuracy: 0.6950
# Epoch 47/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 5.1432 - val_accuracy: 0.6880
# Epoch 48/50
# 100/100 [==============================] - 11s 106ms/step - loss: 1.9983e-07 - accuracy: 1.0000 - val_loss: 5.3555 - val_accuracy: 0.6880
# Epoch 49/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0920 - accuracy: 0.9935 - val_loss: 7.5680 - val_accuracy: 0.6850
# Epoch 50/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0165 - accuracy: 0.9970 - val_loss: 5.6562 - val_accuracy: 0.6930

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " is a dog")
    
  else:
    print(fn + " is a cat")
# Out:
#      <input type="file" id="files-e2a778a9-d7a7-4e3b-b459-4225406c1324" name="files[]" multiple disabled />
#      <output id="result-e2a778a9-d7a7-4e3b-b459-4225406c1324">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-14-5c3a72c8711b> in <module>()
#       4 from keras.preprocessing import image
#       5
# ----> 6 uploaded=files.upload()
#       7
#       8 for fn in uploaded.keys():
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Cannot read property '_uploadFiles' of undefined

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = keras.Model(inputs = [model.input], outputs = [successive_outputs])

# Let's prepare a random input image of a cat or dog from the training set.
cat_img_files = [os.path.join(train_cats_dir, f) for f in train_cat_fnames]
dog_img_files = [os.path.join(train_dogs_dir, f) for f in train_dog_fnames]

img_path = random.choice(cat_img_files + dog_img_files)
img = load_img(img_path, target_size=(150, 150))  # this is a PIL image

x   = img_to_array(img)                           # Numpy array with shape (150, 150, 3)
x   = x.reshape((1,) + x.shape)                   # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255.0

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# Now let's display our representations
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )

# %%
successive_outputs = [layer.output for layer in model.layers[1:]]

# %%
successive_outputs

# %%
tf.__version__

# %%
keras.__version__

# %%
keras.models.Model()
